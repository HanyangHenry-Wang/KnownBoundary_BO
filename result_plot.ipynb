# %%
import  os
import numpy as np
import matplotlib.pyplot as plt

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_logGP_TEI'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*-ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')
# Out:
# Text(0.5, 1.0, 'Branin2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')
# Out:
# Text(0.5, 1.0, 'Beale2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_logGP_TEI'), delimiter=',')

fstar = -3.86278
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')
# Out:
# Text(0.5, 1.0, 'Hartmann3D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D')
# Out:
# Text(0.5, 1.0, 'Powell4D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = np.log10(np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Rosenbrock5D')
# Out:
# Text(0.5, 1.0, 'Rosenbrock5D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Ackley7D_EI'), delimiter=',')
#BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'results/Ackley7D_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'results/Ackley7D_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Ackley7D_logGP_EI'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP+EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

# total_record = (np.array(BO_MES)-fstar)
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP+MES*',color='#c22f2f')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')


total_record = (np.array(BO_ERM)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP*+ERM*',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*+TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')
# Out:
# Text(0.5, 1.0, 'Ackley7D')

# %% [markdown]
# # TEI and EI comparison

# %%
Warped_BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_logGP_EI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Branin2D_logGP_TEI'), delimiter=',')

fstar = 0.397887
N = 20

total_record = np.log10(np.array(Warped_BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')
# Out:
# Text(0.5, 1.0, 'Branin2D')

# %%
Warped_BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_logGP_EI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Beale2D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(Warped_BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')
# Out:
# Text(0.5, 1.0, 'Beale2D')

# %%
Warped_BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_logGP_EI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Hartmann3D_logGP_TEI'), delimiter=',')

fstar = -3.86278
N = 20

total_record = np.log10(np.array(Warped_BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Hartmann3D')
# Out:
# Text(0.5, 1.0, 'Hartmann3D')

# %%
Warped_BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_logGP_EI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Powell4D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(Warped_BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D')
# Out:
# Text(0.5, 1.0, 'Powell4D')

# %%
Warped_BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_logGP_EI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'results/Rosenbrock5D_logGP_TEI'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(Warped_BO_EI)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')


total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP*-TEI*',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Rosenbrock5D')
# Out:
# Text(0.5, 1.0, 'Rosenbrock5D')
