# %%
import  os
import numpy as np
import matplotlib.pyplot as plt

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_BO_MES'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_BO_ERM'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_BO_TEI'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Branin2D_logBO_TEI2'), delimiter=',')

fstar = 0.397887
N = 20

total_record = (np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = (np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Branin2D')
# Out:
# Text(0.5, 1.0, 'Branin2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Beale2D_logBO_TEI2'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = (np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Beale2D')
# Out:
# Text(0.5, 1.0, 'Beale2D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Hartmann3D_logBO_TEI2'), delimiter=',')

fstar = -3.86278
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = np.log10(np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Hartmann3D')
# Out:
# Text(0.5, 1.0, 'Hartmann3D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Levy4D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Levy4D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Levy4D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Levy4D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Levy4D_logBO_TEI2'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = (np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Levy4D')
# Out:
# Text(0.5, 1.0, 'Levy4D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Powell4D_logBO_TEI2'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = (np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Powell4D')
# Out:
# Text(0.5, 1.0, 'Powell4D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Rosenbrock5D_logBO_TEI2'), delimiter=',')

fstar = 0.
N = 20

total_record = np.log10(np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.log10(np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = np.log10(np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.log10(np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = np.log10(np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('log regret')

plt.legend()
plt.title('Rosenbrock5D')
# Out:
# Text(0.5, 1.0, 'Rosenbrock5D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/Ackley7D_logBO_TEI2'), delimiter=',')

fstar = 0.
N = 20

total_record = (np.array(BO_EI)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = (np.array(BO_MES)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

# total_record = (np.array(BO_TEI)-fstar)[:N,:]
# mean = np.mean(total_record,axis=0)
# std = np.std(total_record,axis=0)
# iter = np.array(range(mean.shape[0]))
# plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
# plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = (np.array(BO_ERM)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record = (np.array(Warped_BO_TEI2)-fstar)[:N,:]
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('regret')

plt.legend()
plt.title('Ackley7D')
# Out:
# Text(0.5, 1.0, 'Ackley7D')

# %%
BO_EI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/XGBoost_BO_EI'), delimiter=',')
BO_MES = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/XGBoost_BO_MES'), delimiter=',')
BO_TEI = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/XGBoost_BO_TEI'), delimiter=',')
BO_ERM = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/XGBoost_BO_ERM'), delimiter=',')
Warped_BO_TEI2 = np.genfromtxt(os.path.join(os.getcwd(),'exp_res/XGBoost_logBO_TEI2'), delimiter=',')


N = 20

total_record = np.array(BO_EI)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-EI',color='blue')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='blue')

total_record = np.array(BO_MES)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-MES*',color='#c22f2f')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='#c22f2f')

total_record = np.array(BO_TEI)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='GP-TEI',color='green')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='green')

total_record = np.array(BO_ERM)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='transformed GP-ERM',color='black')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='black')

total_record =  np.array(Warped_BO_TEI2)
mean = np.mean(total_record,axis=0)
std = np.std(total_record,axis=0)
iter = np.array(range(mean.shape[0]))
plt.plot(mean,linewidth=3,label='logGP-TEI',color='yellow')
plt.fill_between(iter, mean-std/np.sqrt(N), mean+std/np.sqrt(N),alpha=0.25,color='yellow')


plt.xlabel('iteration')
plt.ylabel('accuracy')

plt.legend()
plt.title('XGBoost6D')
# Out:
# Text(0.5, 1.0, 'XGBoost6D')
